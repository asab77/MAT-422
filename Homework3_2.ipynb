# %% [markdown]
# <a href="https://colab.research.google.com/github/asab77/MAT-422/blob/main/Homework3_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# Define the variable and the function
x = sp.symbols('x')
f = 1 / (x - 1)

# Calculate the limit of f(x) as x approaches 1
limit_at_1 = sp.limit(f, x, 1)
print(f"The limit of 1/(x - 1) as x approaches 1 is: {limit_at_1}")

# Plot the function to show the behavior near the discontinuity
x_vals = np.linspace(0, 2, 400)
y_vals = 1 / (x_vals - 1)

plt.plot(x_vals, y_vals)
plt.title('Plot of 1/(x - 1)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.show()
# Out:
# The limit of 1/(x - 1) as x approaches 1 is: oo

# %% [markdown]
# ### Limits and Continuity
#
# In this section, we will explore the concept of limits using Python. We will calculate the limit of a function and also visualize its behavior to understand how it behaves near discontinuities.
#
# We will demonstrate how to calculate the limit of the function:
#
# \[
# f(x) = \frac{1}{x - 1}
# \]
#
# as \( x \) approaches 1, which leads to a discontinuity. We will use Python to calculate the limit and plot the function to observe its behavior near this point.

# %%
# Define a function for differentiation
f = x**3 - 5*x**2 + 2*x + 1

# Compute the derivative
f_prime = sp.diff(f, x)
print(f"The derivative of {f} is: {f_prime}")

# Plot the original function and its derivative
x_vals = np.linspace(-2, 4, 100)
f_vals = [f.subs(x, val) for val in x_vals]
f_prime_vals = [f_prime.subs(x, val) for val in x_vals]

plt.plot(x_vals, f_vals, label="f(x) = x^3 - 5x^2 + 2x + 1")
plt.plot(x_vals, f_prime_vals, label="f'(x)", linestyle='--')
plt.legend()
plt.title('Function and Derivative')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()
# Out:
# The derivative of x**3 - 5*x**2 + 2*x + 1 is: 3*x**2 - 10*x + 2

# %% [markdown]
# ### Derivatives
#
# Derivatives describe the rate at which a function changes. In this section, we will compute the derivative of a function using Python's `sympy` library and visualize both the function and its derivative.
#
# We will differentiate the following function:
#
# \[
# f(x) = x^3 - 5x^2 + 2x + 1
# \]
#
# After calculating the derivative, we will plot both the original function and its derivative to understand the relationship between them.

# %%
# Define a function for Taylor expansion
f = sp.sin(x)

# Compute the Taylor series expansion around x = 0, up to the 4th degree
taylor_series = sp.series(f, x, 0, 5)
print(f"Taylor series of sin(x) around x=0 (up to 4th degree): {taylor_series}")

# Plot the actual function and its Taylor series approximation
x_vals = np.linspace(-2 * np.pi, 2 * np.pi, 400)
f_vals = np.sin(x_vals)
taylor_approx = x_vals - (x_vals**3) / 6 + (x_vals**5) / 120

plt.plot(x_vals, f_vals, label='sin(x)')
plt.plot(x_vals, taylor_approx, label="Taylor Approximation (4th degree)", linestyle='--')
plt.legend()
plt.title('sin(x) vs Taylor Series Approximation')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()
# Out:
# Taylor series of sin(x) around x=0 (up to 4th degree): x - x**3/6 + O(x**5)

# %% [markdown]
# ### Taylor's Theorem
#
# Taylor's Theorem allows us to approximate a smooth function as a polynomial. The Taylor series of a function provides an approximation of the function near a given point.
#
# We will compute the Taylor series expansion of \( \sin(x) \) around \( x = 0 \), up to the 4th degree, and visualize how well the Taylor approximation matches the actual function.
#
# The Taylor series of \( \sin(x) \) around \( x = 0 \) is:
#
# \[
# \sin(x) \approx x - \frac{x^3}{3!} + \frac{x^5}{5!}
# \]
